# %%
from sklearn.ensemble import RandomForestRegressor

# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import json

import matplotlib.pyplot as plt
import sqlalchemy 
from sqlalchemy import create_engine
from pathlib import Path
import numpy as np
from functools import reduce

engine = create_engine('postgres://tcccinxdlfzchw:86b3a71b125f827c343a88d71811fa2096744455e75abd5b5e15077bb7a910cb@ec2-50-19-171-158.compute-1.amazonaws.com:5432/d2lr09vchdiec3')

# %%
population_density_df = pd.read_sql_query("SELECT * FROM population_density_by_state", con=engine)
flu_df = pd.read_sql_query("SELECT * FROM flu_percentages", con=engine)
uninsured_df = pd.read_sql_query("SELECT * FROM uninsured_rates_by_state", con=engine)
gdp_df = pd.read_sql_query("SELECT * FROM cleaned_gbp_csv", con=engine)
pci_df = pd.read_sql_query("SELECT * FROM pci_by_state_cleaned_csv", con=engine)

# %%
population_density_df
# Out:
#              State          xx  2016_population_density  \
# 0          Alabama   50,645.39                    96.03
# 1           Alaska   570640.61                     1.30
# 2          Arizona  113,593.91                    61.10
# 3         Arkansas   52,035.35                    57.46
# 4       California  155,779.03                   251.43
# 5         Colorado  103,641.75                    53.45
# 6      Connecticut    4,842.49                   738.91
# 7         Delaware    1,948.66                   486.96
# 10         Georgia   57,513.37                   179.12
# 11          Hawaii     6422.81                   222.26
# 12           Idaho   82,643.20                    20.36
# 13        Illinois   55,518.76                   230.92
# 14         Indiana   35,826.02                   185.18
# 15            Iowa   55,856.99                    56.06
# 16          Kansas   81,758.64                    35.60
# 17        Kentucky   39,486.27                   112.40
# 18       Louisiana   43,204.04                   108.28
# 19           Maine   30,842.99                    43.16
# 20        Maryland    9,707.38                   618.43
# 21   Massachusetts    7,800.03                   874.82
# 22        Michigan   56,538.85                   176.00
# 23       Minnesota   79,626.59                    69.36
# 24     Mississippi   46,923.36                    63.68
# 25        Missouri   68,741.60                    88.55
# 26         Montana  145,545.78                     7.15
# 27        Nebraska   76,824.26                    24.80
# 28          Nevada  109,781.15                    26.58
# 29   New Hampshire    8,952.55                   149.94
# 30      New Jersey    7,354.08                  1206.25
# 31      New Mexico  121,298.19                    17.24
# 32        New York   47,126.45                   416.61
# 33  North Carolina   48,617.96                   208.87
# 34    North Dakota   69,000.67                    10.93
# 35            Ohio   40,860.79                   284.73
# 36        Oklahoma   68,594.88                    57.24
# 37          Oregon   95,988.05                    42.61
# 38    Pennsylvania   44,742.66                   285.68
# 39    Rhode Island    1,033.98                  1022.04
# 40  South Carolina   30,060.74                   164.93
# 41    South Dakota   75,811.13                    11.38
# 42       Tennessee   41,234.92                   161.17
# 43           Texas  261,231.59                   106.86
# 44            Utah   82,169.46                    37.02
# 45         Vermont       9,217                    67.67
# 46        Virginia   39,490.13                   212.97
# 47      Washington   66,455.49                   109.77
# 48   West Virginia   24,038.32                    76.17
# 49       Wisconsin   54,157.76                   106.59
# 50         Wyoming   97,093.07                     6.02
#
#     2017_population_density  2018_population_density  2019_population_density
# 0                     96.25                    96.51                    96.81
# 1                      1.30                     1.29                     1.28
# 2                     62.01                    63.01                    64.08
# 26         Montana                  8.1                  8.5
# 27        Nebraska                  8.6                  8.3
# 28          Nevada                 11.4                 11.2
# 29   New Hampshire                  5.9                  5.8
# 30      New Jersey                  8.0                  7.7
# 31      New Mexico                  9.2                  9.1
# 32        New York                  6.1                  5.7
# 33  North Carolina                 10.4                 10.7
# 34    North Dakota                  7.0                  7.5
# 35            Ohio                  5.6                  6.0
# 36        Oklahoma                 13.8                 14.2
# 37          Oregon                  6.2                  6.8
# 38    Pennsylvania                  5.6                  5.5
# 39    Rhode Island                  4.3                  4.6
# 40  South Carolina                 10.0                 11.0
# 41    South Dakota                  8.7                  9.1
# 42       Tennessee                  9.0                  9.5
# 43           Texas                 16.6                 17.3
# 44            Utah                  8.8                  9.2
# 45         Vermont                  3.7                  4.6
# 46        Virginia                  8.7                  8.8
# 47      Washington                  6.0                  6.1
# 48   West Virginia                  5.3                  6.1
# 49       Wisconsin                  5.3                  5.4
# 50         Wyoming                 11.5                 12.3
#
#     Uninsured Rate 2018  Uninsured Rate 2019
# 0                  10.0                  9.7
# 1                  12.0                 12.2
# 2                  10.0                 11.3
# 3                   8.0                  9.1
# 4                   7.0                  7.7
# 5                   7.0                  8.0
# 6                   5.0                  5.9
# 7                   5.0                  6.6
# 10                 13.0                 13.4
# 11                  4.0                  4.2
# 12                 11.0                 10.8
# 13                  7.0                  7.4
# 14                  8.0                  8.7
# 15                  4.0                  5.0
# 16                  8.0                  9.2
# 17                  5.0                  6.4
# 18                  8.0                  8.9
# 19                  8.0                  8.0
# 20                  6.0                  6.0
# 21                  2.0                  3.0
# 22                  5.0                  5.8
# 23                  4.0                  4.9
# 24                 12.0                 13.0
# 25                  9.0                 10.0
# 26                  8.0                  8.3
# 27                  8.0                  8.3
# 28                 11.0                 11.4
# 29                  5.0                  6.3
# 30                  7.0                  7.9
# 31                  9.0                 10.0
# 32                  5.0                  5.2
# 33                 10.0                 11.3
# 34                  7.0                  6.9
# 35                  6.0                  6.6
# 36                 14.0                 14.3
# 37                  7.0                  7.2
# 38                  5.0                  5.8
# 39                  4.0                  4.1
# 40                 10.0                 10.8
# 41                  9.0                 10.2
# 42                 10.0                 10.1
# 43                 17.0                 18.4
# 44                  9.0                  9.7
# 45                  4.0                  4.5
# 46                  8.0                  7.9
# 47                  6.0                  6.6
# 48                  6.0                  6.7
# 49                  5.0                  5.7
# 50                 10.0                 12.3

# %%
pci_df
# Out:
#    column1     2016     2017     2018     2019
# 0   ALPCPI  39536.0  41030.0  42710.0  44145.0
# 1   AKPCPI  56302.0  57394.0  60355.0  62806.0
# 2   AZPCPI  40801.0  42590.0  44597.0  46058.0
# 3   ARPCPI  40385.0  41657.0  43325.0  44629.0
# 4   CAPCPI  58048.0  60549.0  63720.0  66619.0
# 5   COPCPI  52475.0  55604.0  58896.0  61157.0
# 6   CTPCPI  69919.0  71740.0  74855.0  77289.0
# 7   DEPCPI  48836.0  50798.0  52930.0  54485.0
# 10  GAPCPI  42896.0  44894.0  46957.0  48236.0
# 11  HIPCPI  51170.0  53433.0  55214.0  57015.0
# 15    147929    152511    154456    158192    160059
# 16    182487    183454    184600    187507    190811
# 17    230434    225361    228819    235021    239967
# 18     53879     55088     55964     57302     58793
# 19    349146    359987    365857    368810    374039
# 20    471979    479184    490874    507806    519961
# 21    442287    451025    457341    467828    471648
# 22    316863    321980    327667    337215    341041
# 23    100013    100412    101071    102061    102656
# 24    276316    276210    279264    284696    287659
# 25     45042     44580     45480     46627     47916
# 26    110752    111611    113754    115087    117395
# 27    134892    138638    143590    149663    153728
# 28     71419     73022     74253     76165     77240
# 29    535284    540380    540656    549000    556731
# 30     91679     91713     91772     93870     98765
# 31   1372232   1397723   1424905   1467076   1490678
# 32    469535    477523    489026    501955    511539
# 33     55067     51137     51291     53472     53930
# 34    579943    585044    592725    606141    615474
# 35    193237    188063    188157    193204    197900
# 36    191864    201059    209581    219279    225336
# 37    682527    691316    695560    708856    726165
# 38     52957     53030     52727     53135     53668
# 39    190294    196477    202644    209012    214933
# 40     45371     45733     46023     47287     47559
# 41    302970    308157    314849    323316    328406
# 42   1595969   1606579   1651329   1715231   1764357
# 43    141602    147555    153986    162574    168792
# 44     28876     29206     29312     29565     29806
# 45    455830    460185    468125    478835    489168
# 46    446628    463974    489435    524486    548686
# 47     70332     69276     69743     71858     72340
# 48    288260    291320    294151    303767    308044
# 49     39899     38079     37866     38696     39214

# %%
population_density_df.columns=["State","xx","2016_population_density","2017_population_density", "2018_population_density", "2019_population_density"]

# %%
#Create dataframes to be merged
flu_s1_2016 = pd.DataFrame(flu_df['2016_cases_percent'].values, columns=['2016 Infection Rates'], index=pd.Series(population_density_df["State"]))
flu_s2_2017 = pd.DataFrame(flu_df['2017_cases_percent'].values, columns=['2017 Infection Rates'], index=pd.Series(population_density_df["State"]))
flu_s3_2018 = pd.DataFrame(flu_df['2018_cases_percent'].values, columns=['2018 Infection Rates'], index=pd.Series(population_density_df["State"]))
flu_s4_2019 = pd.DataFrame(flu_df['2019_cases_percent'].values, columns=['2019 Infection Rates'], index=pd.Series(population_density_df["State"]))

population_density_s1_2016 = pd.DataFrame(population_density_df['2016_population_density'].values, columns=['2016_population_density'], index=pd.Series(population_density_df["State"]))
population_density_s2_2017 = pd.DataFrame(population_density_df['2017_population_density'].values, columns=['2017_population_density'], index=pd.Series(population_density_df["State"]))
population_density_s3_2018 = pd.DataFrame(population_density_df['2018_population_density'].values, columns=['2018_population_density'], index=pd.Series(population_density_df["State"]))
population_density_s4_2019 = pd.DataFrame(population_density_df['2019_population_density'].values, columns=['2019_population_density'], index=pd.Series(population_density_df["State"]))

uninsured_rates_s1_2016 = pd.DataFrame(uninsured_df['Uninsured Rate 2016'].values, columns=['Uninsured Rate 2016'], index=pd.Series(population_density_df["State"]))
uninsured_rates_s2_2017 = pd.DataFrame(uninsured_df['Uninsured Rate 2017'].values, columns=['Uninsured Rate 2017'], index=pd.Series(population_density_df["State"]))
uninsured_rates_s3_2018 = pd.DataFrame(uninsured_df['Uninsured Rate 2018'].values, columns=['Uninsured Rate 2018'], index=pd.Series(population_density_df["State"]))
uninsured_rates_s4_2019 = pd.DataFrame(uninsured_df['Uninsured Rate 2019'].values, columns=['Uninsured Rate 2019'], index=pd.Series(population_density_df["State"]))

gdp_s1_2016 = pd.DataFrame(gdp_df['gdp_2016'].values, columns=['GDP 2016'], index=pd.Series(population_density_df["State"]))
gdp_s2_2017 = pd.DataFrame(gdp_df['gdp_2017'].values, columns=['GDP 2017'], index=pd.Series(population_density_df["State"]))
gdp_s3_2018 = pd.DataFrame(gdp_df['gdp_2018'].values, columns=['GDP 2018'], index=pd.Series(population_density_df["State"]))
gdp_s4_2019 = pd.DataFrame(gdp_df['gdp_2019'].values, columns=['GDP 2019'], index=pd.Series(population_density_df["State"]))

pci_s1_2016 = pd.DataFrame(pci_df['2016'].values, columns=['2016 PCI'], index=pd.Series(population_density_df["State"]))
pci_s2_2017 = pd.DataFrame(pci_df['2017'].values, columns=['2017 PCI'], index=pd.Series(population_density_df["State"]))
pci_s3_2018 = pd.DataFrame(pci_df['2018'].values, columns=['2018 PCI'], index=pd.Series(population_density_df["State"]))
pci_s4_2019 = pd.DataFrame(pci_df['2019'].values, columns=['2019 PCI'], index=pd.Series(population_density_df["State"]))

# %%
df_list_2016 = [flu_s1_2016, population_density_s1_2016, uninsured_rates_s1_2016, gdp_s1_2016, pci_s1_2016]

# %%
df_list_2017 = [flu_s2_2017, population_density_s2_2017, uninsured_rates_s2_2017, gdp_s2_2017, pci_s2_2017]

# %%
df_list_2018 = [flu_s3_2018, population_density_s3_2018, uninsured_rates_s3_2018, gdp_s3_2018, pci_s3_2018]

# %%
df_list_2019 = [flu_s4_2019, population_density_s4_2019, uninsured_rates_s4_2019, gdp_s4_2019, pci_s4_2019]

# %%
df_2016 = reduce(lambda  left,right: pd.merge(left,right, left_index=True, right_index=True,
                                            how='outer'), df_list_2016)
df_2017 = reduce(lambda  left,right: pd.merge(left,right, left_index=True, right_index=True,
                                            how='outer'), df_list_2017)
df_2018 = reduce(lambda  left,right: pd.merge(left,right, left_index=True, right_index=True,
                                            how='outer'), df_list_2018)
df_2019 = reduce(lambda  left,right: pd.merge(left,right, left_index=True, right_index=True,
                                            how='outer'), df_list_2019)

# %%
df_2017
# Out:
#                 2017 Infection Rates  2017_population_density  \
# State
# Alabama                     0.551402                    96.25
# Alaska                      0.446938                     1.30
# Arizona                     0.320031                    62.01
# Arkansas                    0.174888                    57.68
# California                  0.117121                   252.66
# Colorado                    0.096011                    54.15
# Connecticut                 0.091932                   737.90
# Delaware                    0.038043                   491.02
# Georgia                     0.693379                   181.01
# Hawaii                      0.118717                   221.77
# Idaho                       0.034232                    20.78
# Illinois                    0.360557                   230.17
# Indiana                     0.072979                   185.84
# Iowa                        0.037720                    56.24
# Kansas                      0.266647                    35.58
# Kentucky                    0.299802                   112.75
# Louisiana                   1.897203                   108.10
# Maine                       0.140116                    43.27
# Maryland                    0.123957                   620.55
# Massachusetts               0.258230                   879.46
# Michigan                    0.196609                   176.39
# Minnesota                   0.113632                    69.90
# Mississippi                 1.123871                    63.69
# Missouri                    0.095486                    88.84
# Montana                     0.017482                     7.23
# Nebraska                    0.217073                    24.94
# Nevada                      0.307013                    27.05
# New Hampshire               0.080294                   150.66
# New Jersey                  0.305609                  1208.24
# New Mexico                  0.557323                    17.24
# New York                    0.088971                   415.68
# North Carolina              0.137560                   211.20
# North Dakota                0.134315                    10.94
# Ohio                        0.095955                   285.35
# Oklahoma                    0.280262                    57.31
# Oregon                      0.262258                    43.17
# Pennsylvania                0.143185                   285.80
# Rhode Island                0.226775                  1020.98
# South Carolina              0.187024                   167.04
# South Dakota                0.871953                    11.51
# Tennessee                   0.165216                   162.70
# Texas                       0.195114                   108.31
# Utah                        0.169040                    37.74
# Vermont                     0.187397                    67.74
# Virginia                    1.162450                   214.32
# Washington                  0.025137                   111.70
# West Virginia               0.688606                    75.59
# Wisconsin                   0.075144                   106.91
# Wyoming                     0.521997                     5.96
#
#                 Uninsured Rate 2017  GDP 2017  2017 PCI
# State
# Alabama                         9.4    193693   41030.0
# Alaska                         13.7     52825   57394.0
# Arizona                        10.1    302117   42590.0
# Arkansas                        7.9    114950   41657.0
# California                      7.2   2628314   60549.0
# Colorado                        7.5    328510   55604.0
# Connecticut                     5.5    248077   71740.0
# Delaware                        5.4     61851   50798.0
# Georgia                        13.4    519452   44894.0
# Hawaii                          3.8     81039   53433.0
# Idaho                          10.1     68412   42268.0
# Illinois                        6.8    752459   54252.0
# Indiana                         8.2    322969   45244.0
# Iowa                            4.7    168976   47662.0
# Kansas                          8.7    154456   48883.0
# Kentucky                        5.4    184600   40904.0
# Louisiana                       8.4    228819   43932.0
# Maine                           8.1     55964   46565.0
# Maryland                        6.1    365857   60758.0
# Massachusetts                   2.8    490874   68442.0
# Michigan                        5.2    457341   45948.0
# Minnesota                       4.4    327667   54960.0
# Mississippi                    12.0    101071   36536.0
# Missouri                        9.1    279264   45342.0
# Montana                         8.5     45480   46199.0
# Nebraska                        8.3    113754   50645.0
# Nevada                         11.2    143590   47650.0
# New Hampshire                   5.8     74253   58759.0
# New Jersey                      7.7    540656   64983.0
# New Mexico                      9.1     91772   39747.0
# New York                        5.7   1424905   65814.0
# North Carolina                 10.7    489026   44409.0
# North Dakota                    7.5     51291   52736.0
# Ohio                            6.0    592725   46829.0
# Oklahoma                       14.2    188157   43794.0
# Oregon                          6.8    209581   48762.0
# Pennsylvania                    5.5    695560   53306.0
# Rhode Island                    4.6     52727   52644.0
# South Carolina                 11.0    202644   42227.0
# South Dakota                    9.1     46023   49787.0
# Tennessee                       9.5    314849   45233.0
# Texas                          17.3   1651329   48394.0
# Utah                            9.2    153986   44178.0
# Vermont                         4.6     29312   51697.0
# Virginia                        8.8    468125   55631.0
# Washington                      6.1    489435   58437.0
# West Virginia                   6.1     69743   38927.0
# Wisconsin                       5.4    294151   49264.0
# Wyoming                        12.3     37866   56524.0

# %%
# Define the features set.
X = df_2016.copy()
X2 = df_2017.copy()
X3 = df_2018.copy()
X4 = df_2019.copy()

X = X.drop("2016 Infection Rates", axis=1)
X2 = X2.drop("2017 Infection Rates", axis=1)
X3 = X3.drop("2018 Infection Rates", axis=1)
X4 = X4.drop("2019 Infection Rates", axis=1)

# %%
y = df_2016["2016 Infection Rates"].ravel()
y2 = df_2017["2017 Infection Rates"].ravel()
y3 = df_2018["2018 Infection Rates"].ravel()
y4 = df_2019["2019 Infection Rates"].ravel()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, random_state=78)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, random_state=78)
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, y4, random_state=78)

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)





# Creating a second StandardScaler instance.
scaler2 = StandardScaler()
# Fitting the Standard Scaler with the training data.
X2_scaler = scaler2.fit(X2_train)

# Scaling the data.
X2_train_scaled = X2_scaler.transform(X2_train)
X2_test_scaled = X2_scaler.transform(X2_test)





# Creating a third StandardScaler instance.
scaler3 = StandardScaler()
# Fitting the Standard Scaler with the training data.
X3_scaler = scaler3.fit(X3_train)

# Scaling the data.
X3_train_scaled = X3_scaler.transform(X3_train)
X3_test_scaled = X3_scaler.transform(X3_test)





# Creating a fourth StandardScaler instance.
scaler4 = StandardScaler()
# Fitting the Standard Scaler with the training data.
X4_scaler = scaler4.fit(X_train)

# Scaling the data.
X4_train_scaled = X4_scaler.transform(X4_train)
X4_test_scaled = X4_scaler.transform(X4_test)

# %%
# Create a random forest regressor
rf_model = RandomForestRegressor(n_estimators=256, random_state=78) 
# Create a random forest regressor
rf_model2 = RandomForestRegressor(n_estimators=256, random_state=78) 
# Create a random forest regressor
rf_model3 = RandomForestRegressor(n_estimators=256, random_state=78) 
# Create a random forest regressor
rf_model4 = RandomForestRegressor(n_estimators=256, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)
# Fitting the model
rf_model2 = rf_model2.fit(X2_train_scaled, y2_train)
# Fitting the model
rf_model3 = rf_model3.fit(X3_train_scaled, y3_train)
# Fitting the model
rf_model4 = rf_model4.fit(X4_train_scaled, y4_train)

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)
# Making predictions using the testing data.
predictions2 = rf_model2.predict(X2_test_scaled)
# Making predictions using the testing data.
predictions3 = rf_model3.predict(X3_test_scaled)
# Making predictions using the testing data.
predictions4 = rf_model4.predict(X4_test_scaled)

# %%
mse = mean_squared_error(y_test, predictions)
mse2 = mean_squared_error(y2_test, predictions2)
mse3 = mean_squared_error(y3_test, predictions3)
mse4 = mean_squared_error(y4_test, predictions4)

rmse = np.sqrt(mse)
rmse2 = np.sqrt(mse2)
rmse3 = np.sqrt(mse3)
rmse4 = np.sqrt(mse4)

# %%
rmse
# Out:
# 0.15256433150762522

# %%
rmse2
# Out:
# 0.28686415526838405

# %%
rmse3
# Out:
# 0.32344282833962584

# %%
rmse4
# Out:
# 0.3577264837651607

# %%
infoToParse = df_2016.to_json(orient="columns", path_or_buf = "/Users/ryanlindsey/Documents/GitHub/GoingViral/HeatMap Resources/jsontoparse.json")
